# %% [markdown]
# ## Bamboo Spike
#
# In this notebook, we're going to go through the results of using many Edpoints to abstract data from Bamboo API
#
# Since we're trying to create reports to centralize the data into Bamboo.
#
# All the documentation about this process and why you can find it out on the  [Conflucence documentation](https://devsavant.atlassian.net/wiki/spaces/DTDEA/pages/2266333203/PoC+-+BambooHR+Webhook)
#
# All the enpoints and request URL you can find it out on [Bamboo Documentation](https://documentation.bamboohr.com/docs).
#
# ### What we'll end up with
#
# Since we already have a pre-created reports we can create those on Bamboo and consume taht periodically depend on the necesity of actualization of DevSavant Database

# %%
# Import necessary libraries 
import requests
import pandas as pd

# %%
TOKEN = 'token'
authorization = 'Basic Auth'

# %%
#get list of tabular fields
url = "https://api.bamboohr.com/api/gateway.php/devsavant/v1/meta/tables/"
headers = {
    "Accept": "application/json",
    "authorization": "Basic NGM4ZThlNzE4ODdlYjE2MTg3OGIyMDBiZmI2MTE5OGUyNzk1ZDAwODpkZXZzYXZhbnQ="
}
response = requests.get(url, headers=headers)
fields = response.json()

# %%
# Orginize data from the endpoint above
tables = {}
for x in range(len(fields)):
    dict_tempo = {}
    for j in fields[x]['fields']:
        dict_tempo[j['alias']] = j['name']
    tables[str(fields[x]['alias'])] = dict_tempo
tables
# Out:
# {'jobInfo': {'date': 'Job Information: Date',
#   'location': 'Location',
#   'department': 'Department',
#   'division': 'Division',
#   'jobTitle': 'Job Title',
#   'reportsTo': 'Reporting to'},
#  'employmentStatus': {'date': 'Employment Status: Date',
#   'employmentStatus': 'Employment Status',
#   'comment': 'Employment status comments',
#   'terminationReasonId': 'Termination Reason',
#   'terminationTypeId': 'Termination Type',
#   'terminationRehireId': 'Eligible For Re-hire'},
#  'compensation': {'startDate': 'Compensation: Date',
#   'rate': 'Pay rate',
#   'type': 'Pay type',
#   'exempt': 'Overtime Status',
#   'reason': 'Compensation Change Reason',
#   'comment': 'Compensation comments',
#   'paidPer': 'Paid per',
#   'paySchedule': 'Pay Schedule',
#   'overtimeRate': 'Overtime Rate'},
#  'dependents': {'firstName': 'Dependent First Name',
#   'middleName': 'Dependent Middle Name',
#   'lastName': 'Dependent Last Name',
#   'relationship': 'Dependent Relationship',
#   'gender': 'Dependent Gender',
#   'addressLine1': 'Dependent Street 1',
#   'addressLine2': 'Dependent Street 2',
#   'ssn': 'Dependent SSN',
#   'dateOfBirth': 'Dependent Birth Date',
#   'city': 'Dependent City',
#   'state': 'Dependent State',
#   'homePhone': 'Dependent Home Phone',
#   'country': 'Dependent Country',
#   'zipcode': 'Dependent ZIP'},
#  'contacts': {'name': 'Emergency Contact Name',
#   'relationship': 'Emergency Contact Relationship',
#   'homePhone': 'Emergency Contact Home Phone',
#   'addressLine1': 'Emergency Contact Street 1',
#   'addressLine2': 'Emergency Contact Street 2',
#   'mobilePhone': 'Emergency Contact Mobile Phone',
#   'email': 'Emergency Contact Email',
#   'zipcode': 'Emergency Contact ZIP Code',
#   'city': 'Emergency Contact City',
#   'state': 'Emergency Contact State',
#   'country': 'Emergency Contact Country',
#   'workPhone': 'Emergency Contact Work Phone',
#   'workPhoneExtension': 'Emergency Contact Work Ext',
#   'primaryContact': 'Emergency Contact Primary'},
#  'emergencyContacts': {'name': 'Emergency Contact Name',
#   'relationship': 'Emergency Contact Relationship',
#   'homePhone': 'Emergency Contact Home Phone',
#   'addressLine1': 'Emergency Contact Street 1',
#   'addressLine2': 'Emergency Contact Street 2',
#   'mobilePhone': 'Emergency Contact Mobile Phone',
#   'email': 'Emergency Contact Email',
#   'zipcode': 'Emergency Contact ZIP Code',
#   'city': 'Emergency Contact City',
#   'state': 'Emergency Contact State',
#   'country': 'Emergency Contact Country',
#   'workPhone': 'Emergency Contact Work Phone',
#   'workPhoneExtension': 'Emergency Contact Work Ext',
#   'primaryContact': 'Emergency Contact Primary'},
#  'earnings': {'date': 'Earnings: Date',
#   'priorYear': 'Earnings: Prior Year W2/K1'},
#  'bonus': {'date': 'Bonus: Date',
#   'amount': 'Bonus: Amount',
#   'reason': 'Bonus: Reason',
#   'comment': 'Bonus: Comment'},
#  'commission': {'date': 'Commission: Date',
#   'amount': 'Commission: Amount',
#   'comment': 'Commission: Comment'},
#  'benefit_class': {'date': 'Benefit Class: Date',
#   'class': 'Benefit Class: Class',
#   'changeReason': 'Benefit Class: Change Reason'},
#  'employeeVisas': {'date': 'Visa:Date',
#   'visaType': 'Visa',
#   'country': 'Issuing country',
#   'issued': 'Issued',
#   'expires': 'Expiration',
#   'note': 'Note'},
#  'employeeEducation': {'school': 'College/Institution',
#   'startDate': 'Employee Education: Start Date',
#   'endDate': 'Employee Education: End Date',
#   'degree': 'Degree',
#   'major': 'Major/Specialization',
#   'gpa': 'GPA'},
#  'employeePassports': {'passportNumber': 'Passport Number',
#   'issuedDate': 'Passport: Issued Date',
#   'expiryDate': 'Passport: Expiry Date',
#   'issuingCountry': 'Issuing Country'},
#  'employeeDriverLicenses': {'license': 'Driver License: #',
#   'state': 'Driver License: State',
#   'expirationDate': 'Driver License: Expiration',
#   'driverClassification': 'Driver License: Classification',
#   'dmvViolations': 'Driver License: DMV Violations '},
#  'employeeCertifications': {'title': 'Certifications: Title',
#   'completionDate': 'Certifications: Completion Date',
#   'certificationNumber': 'Certifications: Number',
#   'expirationDate': 'Certifications: Expiration Date',
#   'notes': 'Certifications: Notes'},
#  'employeeStockOptions': {'grantDate': 'Stock Options: Grant Date',
#   'numberOptionsGranted': 'Stock Options: # Options Granted',
#   'optionPrice': 'Stock Options: Option Price',
#   'vestingDate': 'Stock Options: Vesting Date',
#   'plan': 'Stock Options: Plan',
#   'comments': 'Stock Options: Comments'},
#  'employeeAssets': {'category': 'Assets: Category',
#   'description': 'Assets: Description',
#   'serialNumber': 'Assets: Serial Number',
#   'dateLoaned': 'Assets: Date Loaned',
#   'dateReturned': 'Assets: Date Returned',
#   'cost': 'Assets: Cost',
#   'notes': 'Assets: Notes'},
#  'employeeCreditCards': {'cardType': 'Card Type',
#   'numberLast4': 'Card #',
#   'expirationMonth': 'Expiration Month',
#   'expirationYear': 'Expiration Year',
#   'cardLimit': 'Limit'},
#  'employeeCovidTests': {'testDate': 'Testing Tracker: Test Date',
#   'results': 'Testing Tracker: Results',
#   'testType': 'Testing Tracker: Test Type',
#   'testingReason': 'Testing Tracker: Testing Reason',
#   'confirmedByHr': 'Testing Tracker: Confirmed by HR',
#   'officeEligibility': 'Testing Tracker: Office Eligibility',
#   'comments': 'Testing Tracker: Comments'},
#  'employeeCovidVaccinations': {'vaccinationStatus': 'Vaccination History: Vaccination Status',
#   'administrationDate': 'Vaccination History: Administration Date',
#   'vaccineReceived': 'Vaccination History: Vaccine Received',
#   'dosage': 'Vaccination History: Dosage',
#   'verified': 'Vaccination History: Verified',
#   'dateVerified': 'Vaccination History: Date Verified',
#   'officeEligibleDate': 'Vaccination History: Office Eligible Date'},
#  'employeeCovidVaccinationExemptions': {'exemptionDate': 'Vaccination Exemptions: Exemption Date',
#   'exemptionReason': 'Vaccination Exemptions: Exemption Reason',
#   'exemptionDocumentationCollected': 'Vaccination Exemptions: Exemption Documentation Collected',
#   'comments': 'Vaccination Exemptions: Comments'},
#  'employeeCovidExposures': {'exposureDate': 'Exposure Tracker: Exposure Date',
#   'vaccinationStatus': 'Exposure Tracker: Vaccination Status',
#   'notified': 'Exposure Tracker: Notified',
#   'comments': 'Exposure Tracker: Comments'},
#  'customDirectDepositInformation': {'customBankName': 'Bank Name',
#   'customBankAccountType': 'Bank Account Type',
#   'customRoutingNumber': 'Routing Number',
#   'customAccountNumber': 'Account Number',
#   'customSwiftCode': 'Swift Code',
#   'customCountry': 'Country'},
#  'customJob': {'customClientStartDate': 'Start Date',
#   'customClient': 'Client',
#   'customSeniorityfrentealcliente': 'Client Seniority',
#   'customDevSavantTeamlead': 'DevSavant Teamlead',
#   'customDevSavantTechlead': 'DevSavant Techlead',
#   'customProject': 'Project',
#   'customClientLead': 'Client Lead'},
#  'customNetCompensation': {'customEffectiveDate': 'Effective Date',
#   'customPaySchedule': 'Pay Schedule',
#   'customCompanyCost1': 'Company Cost',
#   'customNetPayments1': 'Net Payments',
#   'customSalary': 'Salary',
#   'customFlexibilityScheme1': 'Flexibility Scheme',
#   'customContractType1': 'Contract Type',
#   'customSalaryType1': 'Salary Type',
#   'customChangeReason': 'Change Reason',
#   'customComments1': 'Comments',
#   'customGrossCompensation': 'Gross Compensation',
#   'customHousingBonus1': 'Housing Bonus',
#   'customPayrollCost': 'Payroll Cost'},
#  'customWorkingTool': {'customEffectiveDate1': 'Effective Date',
#   'customAdditionalInformation': 'Additional Information',
#   'customDevolutionDate': 'Devolution Date',
#   'customToolCode': 'Tool Code',
#   'customTool': 'Tool',
#   'customToolInformation': 'Tool Information',
#   'customGuide': 'Guide',
#   'customToolStatus': 'Tool Status'},
#  'customAdditionalInformation1': {'customHeadhunter': 'Headhunter/ Referral',
#   'customHeadhunterCost': 'Headhunter Cost/ Referral Cost',
#   'customReferredfrom': 'Referred from'},
#  'customCareerPath': {'customEffectiveDate2': 'Effective Date',
#   'customSeniority': 'Seniority',
#   'customSublevel': 'Sublevel'},
#  'customSocialBenefits': {'customEffectiveDate3': 'Effective Date',
#   'customCajadecompensación': 'Caja de compensación',
#   'customFondodeCesantías': 'Fondo de Cesantías',
#   'customFondodePensión': 'Fondo de Pensión',
#   'customEPS': 'EPS',
#   'customARL': 'ARL'},
#  'customMedicinaPrepagada': {'customEffectiveDate4': 'Effective Date',
#   'customEntidadMedicinaPrepagada': 'Entidad Medicina Prepagada',
#   'customTipodePlan': 'Tipo de Plan'}}

# %%
# function to get personalized reports
def api_request_reports(fields:list, title:str, token:str):    
    url = "https://api.bamboohr.com/api/gateway.php/devsavant/v1/reports/custom?format=json&onlyCurrent=true"
    headers = {"Accept": "application/json"}
    payload = {
        "title": title,
        "fields": fields
    }
    response = requests.post("https://api.bamboohr.com/api/gateway.php/devsavant/v1/reports/custom?format=json&onlyCurrent=true",
                            auth=(token, 'DevSavant'), 
                            headers=headers, json=payload)
    response.raise_for_status()    
    if response.status_code != 204:
        print('Request ok')        
    return response.json()

# %%
no_usable = {} #fields that we can not call using personalized reports
usable = {} # Usable fileds that we can call using personalized reports
for keys, values in tables.items():
    print("Title: " + str(values.keys()))
    df = pd.DataFrame(api_request_reports(fields = list(values.keys()), title = keys, token = TOKEN)['employees'])
    no_usable[keys] = set(values.keys()).difference(set(df.columns))
    usable[keys] = set(values.keys()).intersection(set(df.columns))
# Out:
# Title: dict_keys(['date', 'location', 'department', 'division', 'jobTitle', 'reportsTo'])
# Request ok
# Title: dict_keys(['date', 'employmentStatus', 'comment', 'terminationReasonId', 'terminationTypeId', 'terminationRehireId'])
# Request ok
# Title: dict_keys(['startDate', 'rate', 'type', 'exempt', 'reason', 'comment', 'paidPer', 'paySchedule', 'overtimeRate'])
# Request ok
# Title: dict_keys(['firstName', 'middleName', 'lastName', 'relationship', 'gender', 'addressLine1', 'addressLine2', 'ssn', 'dateOfBirth', 'city', 'state', 'homePhone', 'country', 'zipcode'])
# Request ok
# Title: dict_keys(['name', 'relationship', 'homePhone', 'addressLine1', 'addressLine2', 'mobilePhone', 'email', 'zipcode', 'city', 'state', 'country', 'workPhone', 'workPhoneExtension', 'primaryContact'])
# Request ok
# Title: dict_keys(['name', 'relationship', 'homePhone', 'addressLine1', 'addressLine2', 'mobilePhone', 'email', 'zipcode', 'city', 'state', 'country', 'workPhone', 'workPhoneExtension', 'primaryContact'])
# Request ok
# Title: dict_keys(['date', 'priorYear'])
# Request ok
# Title: dict_keys(['date', 'amount', 'reason', 'comment'])
# Request ok
# Title: dict_keys(['date', 'amount', 'comment'])
# Request ok
# Title: dict_keys(['date', 'class', 'changeReason'])
# Request ok
# Title: dict_keys(['date', 'visaType', 'country', 'issued', 'expires', 'note'])
# Request ok
# Title: dict_keys(['school', 'startDate', 'endDate', 'degree', 'major', 'gpa'])
# Request ok
# Title: dict_keys(['passportNumber', 'issuedDate', 'expiryDate', 'issuingCountry'])
# Request ok
# Title: dict_keys(['license', 'state', 'expirationDate', 'driverClassification', 'dmvViolations'])
# Request ok
# Title: dict_keys(['title', 'completionDate', 'certificationNumber', 'expirationDate', 'notes'])
# Request ok
# Title: dict_keys(['grantDate', 'numberOptionsGranted', 'optionPrice', 'vestingDate', 'plan', 'comments'])
# Request ok
# Title: dict_keys(['category', 'description', 'serialNumber', 'dateLoaned', 'dateReturned', 'cost', 'notes'])
# Request ok
# Title: dict_keys(['cardType', 'numberLast4', 'expirationMonth', 'expirationYear', 'cardLimit'])
# Request ok
# Title: dict_keys(['testDate', 'results', 'testType', 'testingReason', 'confirmedByHr', 'officeEligibility', 'comments'])
# Request ok
# Title: dict_keys(['vaccinationStatus', 'administrationDate', 'vaccineReceived', 'dosage', 'verified', 'dateVerified', 'officeEligibleDate'])
# Request ok
# Title: dict_keys(['exemptionDate', 'exemptionReason', 'exemptionDocumentationCollected', 'comments'])
# Request ok
# Title: dict_keys(['exposureDate', 'vaccinationStatus', 'notified', 'comments'])
# Request ok
# Title: dict_keys(['customBankName', 'customBankAccountType', 'customRoutingNumber', 'customAccountNumber', 'customSwiftCode', 'customCountry'])
# Request ok
# Title: dict_keys(['customClientStartDate', 'customClient', 'customSeniorityfrentealcliente', 'customDevSavantTeamlead', 'customDevSavantTechlead', 'customProject', 'customClientLead'])
# Request ok
# Title: dict_keys(['customEffectiveDate', 'customPaySchedule', 'customCompanyCost1', 'customNetPayments1', 'customSalary', 'customFlexibilityScheme1', 'customContractType1', 'customSalaryType1', 'customChangeReason', 'customComments1', 'customGrossCompensation', 'customHousingBonus1', 'customPayrollCost'])
# Request ok
# Title: dict_keys(['customEffectiveDate1', 'customAdditionalInformation', 'customDevolutionDate', 'customToolCode', 'customTool', 'customToolInformation', 'customGuide', 'customToolStatus'])
# Request ok
# Title: dict_keys(['customHeadhunter', 'customHeadhunterCost', 'customReferredfrom'])
# Request ok
# Title: dict_keys(['customEffectiveDate2', 'customSeniority', 'customSublevel'])
# Request ok
# Title: dict_keys(['customEffectiveDate3', 'customCajadecompensación', 'customFondodeCesantías', 'customFondodePensión', 'customEPS', 'customARL'])
# Request ok
# Title: dict_keys(['customEffectiveDate4', 'customEntidadMedicinaPrepagada', 'customTipodePlan'])
# Request ok

# %%
no_usable
# Out:
# {'jobInfo': {'date', 'reportsTo'},
#  'employmentStatus': {'comment',
#   'date',
#   'employmentStatus',
#   'terminationReasonId',
#   'terminationRehireId',
#   'terminationTypeId'},
#  'compensation': {'comment', 'paidPer', 'rate', 'reason', 'startDate', 'type'},
#  'dependents': {'addressLine1', 'addressLine2', 'relationship'},
#  'contacts': {'addressLine1',
#   'addressLine2',
#   'email',
#   'name',
#   'primaryContact',
#   'relationship'},
#  'emergencyContacts': {'addressLine1',
#   'addressLine2',
#   'email',
#   'name',
#   'primaryContact',
#   'relationship'},
#  'earnings': {'date', 'priorYear'},
#  'bonus': {'amount', 'comment', 'date', 'reason'},
#  'commission': {'amount', 'comment', 'date'},
#  'benefit_class': {'changeReason', 'class', 'date'},
#  'employeeVisas': {'date', 'expires', 'issued', 'note', 'visaType'},
#  'employeeEducation': {'degree',
#   'endDate',
#   'gpa',
#   'major',
#   'school',
#   'startDate'},
#  'employeePassports': {'expiryDate',
#   'issuedDate',
#   'issuingCountry',
#   'passportNumber'},
#  'employeeDriverLicenses': {'dmvViolations',
#   'driverClassification',
#   'expirationDate',
#   'license'},
#  'employeeCertifications': {'certificationNumber',
#   'completionDate',
#   'expirationDate',
#   'notes',
#   'title'},
#  'employeeStockOptions': {'comments',
#   'grantDate',
#   'numberOptionsGranted',
#   'optionPrice',
#   'plan',
#   'vestingDate'},
#  'employeeAssets': {'category',
#   'cost',
#   'dateLoaned',
#   'dateReturned',
#   'description',
#   'notes',
#   'serialNumber'},
#  'employeeCreditCards': {'cardLimit',
#   'cardType',
#   'expirationMonth',
#   'expirationYear',
#   'numberLast4'},
#  'employeeCovidTests': {'comments',
#   'confirmedByHr',
#   'officeEligibility',
#   'results',
#   'testDate',
#   'testType',
#   'testingReason'},
#  'employeeCovidVaccinations': {'administrationDate',
#   'dateVerified',
#   'dosage',
#   'officeEligibleDate',
#   'vaccinationStatus',
#   'vaccineReceived',
#   'verified'},
#  'employeeCovidVaccinationExemptions': {'comments',
#   'exemptionDate',
#   'exemptionDocumentationCollected',
#   'exemptionReason'},
#  'employeeCovidExposures': {'comments',
#   'exposureDate',
#   'notified',
#   'vaccinationStatus'},
#  'customDirectDepositInformation': {'customAccountNumber',
#   'customBankAccountType',
#   'customBankName',
#   'customCountry',
#   'customRoutingNumber',
#   'customSwiftCode'},
#  'customJob': {'customClient',
#   'customClientLead',
#   'customClientStartDate',
#   'customDevSavantTeamlead',
#   'customDevSavantTechlead',
#   'customProject',
#   'customSeniorityfrentealcliente'},
#  'customNetCompensation': {'customChangeReason',
#   'customComments1',
#   'customCompanyCost1',
#   'customContractType1',
#   'customEffectiveDate',
#   'customFlexibilityScheme1',
#   'customGrossCompensation',
#   'customHousingBonus1',
#   'customNetPayments1',
#   'customPaySchedule',
#   'customPayrollCost',
#   'customSalary',
#   'customSalaryType1'},
#  'customWorkingTool': {'customAdditionalInformation',
#   'customDevolutionDate',
#   'customEffectiveDate1',
#   'customGuide',
#   'customTool',
#   'customToolCode',
#   'customToolInformation',
#   'customToolStatus'},
#  'customAdditionalInformation1': {'customHeadhunter',
#   'customHeadhunterCost',
#   'customReferredfrom'},
#  'customCareerPath': {'customEffectiveDate2',
#   'customSeniority',
#   'customSublevel'},
#  'customSocialBenefits': {'customARL',
#   'customCajadecompensación',
#   'customEPS',
#   'customEffectiveDate3',
#   'customFondodeCesantías',
#   'customFondodePensión'},
#  'customMedicinaPrepagada': {'customEffectiveDate4',
#   'customEntidadMedicinaPrepagada',
#   'customTipodePlan'}}

# %%
usable

# %%
### Get DevSavant fields
url = "https://api.bamboohr.com/api/gateway.php/devsavant/v1/meta/fields/"
headers = {
    "Accept": "application/json",
    "authorization": authorization
}
response = requests.get(url, headers=headers)
field = response.json()
field
# Out:
# [{'id': 4464, 'name': 'Account Number', 'type': 'text'},
#  {'id': 4175, 'name': 'Accrual Level Start Date', 'type': 'date'},
#  {'id': 4481,
#   'name': 'Additional Address Information',
#   'type': 'list',
#   'alias': 'customAdditionalAddressInformation'},
#  {'id': 4603, 'name': 'Additional Information', 'type': 'textarea'},
#  {'id': 8, 'name': 'Address Line 1', 'type': 'text', 'alias': 'address1'},
#  {'id': 9, 'name': 'Address Line 2', 'type': 'text', 'alias': 'address2'},
#  {'id': 4404, 'name': 'Allergies', 'type': 'text', 'alias': 'allergies'},
#  {'id': 4626, 'name': 'ARL', 'type': 'list'},
#  {'id': 4436, 'name': 'Assets: Category', 'type': 'list'},
#  {'id': 4441, 'name': 'Assets: Cost', 'type': 'currency'},
#  {'id': '4441.1', 'name': 'Assets: Cost - Currency code', 'type': 'text'},
#  {'id': 4439, 'name': 'Assets: Date Loaned', 'type': 'date'},
#  {'id': 4440, 'name': 'Assets: Date Returned', 'type': 'date'},
#  {'id': 4437, 'name': 'Assets: Description', 'type': 'text'},
#  {'id': 4442, 'name': 'Assets: Notes', 'type': 'text'},
#  {'id': 4438, 'name': 'Assets: Serial Number', 'type': 'text'},
#  {'id': 4462, 'name': 'Bank Account Type', 'type': 'list'},
#  {'id': 4461, 'name': 'Bank Name', 'type': 'text'},
#  {'id': 1502, 'name': 'Benefit History', 'type': 'benefit_history'},
#  {'id': '4516.8',
#   'name': 'Bereavement leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4516.6',
#   'name': 'Bereavement leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4516.3',
#   'name': 'Bereavement leave - Available Balance',
#   'type': 'int'},
#  {'id': '4516.7',
#   'name': 'Bereavement leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4516.5', 'name': 'Bereavement leave - Days scheduled', 'type': 'int'},
#  {'id': '4516.4',
#   'name': 'Bereavement leave - Days taken (YTD)',
#   'type': 'int'},
#  {'id': '4516.2', 'name': 'Bereavement leave - Policy', 'type': 'text'},
#  {'id': 4516,
#   'name': 'Bereavement leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 6, 'name': 'Birth Date', 'type': 'date', 'alias': 'dateOfBirth'},
#  {'id': 4622, 'name': 'Caja de compensación', 'type': 'list'},
#  {'id': 4588, 'name': 'Change Reason', 'type': 'list'},
#  {'id': 10, 'name': 'City', 'type': 'text', 'alias': 'city'},
#  {'id': 4573, 'name': 'Client', 'type': 'list'},
#  {'id': 4596, 'name': 'Client Lead', 'type': 'list'},
#  {'id': 4575, 'name': 'Client Seniority', 'type': 'list'},
#  {'id': 4293, 'name': 'College/Institution', 'type': 'text'},
#  {'id': 4589, 'name': 'Comments', 'type': 'textarea'},
#  {'id': 4580, 'name': 'Company Cost', 'type': 'currency'},
#  {'id': '4580.1', 'name': 'Company Cost - Currency code', 'type': 'text'},
#  {'id': 4021,
#   'name': 'Compensation: Date',
#   'type': 'date',
#   'alias': 'payRateEffectiveDate'},
#  {'id': 4017,
#   'name': 'Compensation Change Reason',
#   'type': 'list',
#   'alias': 'payChangeReason'},
#  {'id': 4045, 'name': 'Compensation comments', 'type': 'textarea'},
#  {'id': '4020.1', 'name': 'Completed - Category', 'type': 'list'},
#  {'id': '4020.2', 'name': 'Completed - Completed', 'type': 'date'},
#  {'id': '4020.3', 'name': 'Completed - Cost', 'type': 'currency'},
#  {'id': '4020.4', 'name': 'Completed - Credits', 'type': 'int'},
#  {'id': '4020.5', 'name': 'Completed - Hours', 'type': 'int'},
#  {'id': '4020.6', 'name': 'Completed - Instructor', 'type': 'text'},
#  {'id': '4020.7', 'name': 'Completed - Notes', 'type': 'text'},
#  {'id': 4020, 'name': 'Completed - Title', 'type': 'training_type'},
#  {'id': '4497.4', 'name': 'Computer Financing - Company pays', 'type': 'text'},
#  {'id': '4497.7',
#   'name': 'Computer Financing - Company pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': '4497.2',
#   'name': 'Computer Financing - Coverage',
#   'type': 'employee_new_benefit_coverage_type'},
#  {'id': '4497.1',
#   'name': 'Computer Financing - Effective date',
#   'type': 'date'},
#  {'id': '4497.5',
#   'name': 'Computer Financing - Eligibility date',
#   'type': 'date'},
#  {'id': '4497.3',
#   'name': 'Computer Financing - Employee pays',
#   'type': 'text'},
#  {'id': '4497.6',
#   'name': 'Computer Financing - Employee pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': 4497,
#   'name': 'Computer Financing - Status',
#   'type': 'new_benefit_status'},
#  {'id': 4586, 'name': 'Contract Type', 'type': 'list'},
#  {'id': 3991, 'name': 'Country', 'type': 'country', 'alias': 'country'},
#  {'id': 4599, 'name': 'Country', 'type': 'list'},
#  {'id': 4294, 'name': 'Degree', 'type': 'list'},
#  {'id': 4, 'name': 'Department', 'type': 'list', 'alias': 'department'},
#  {'id': 1928, 'name': 'Dependent Birth Date', 'type': 'date'},
#  {'id': 1931, 'name': 'Dependent City', 'type': 'text'},
#  {'id': 3992, 'name': 'Dependent Country', 'type': 'country'},
#  {'id': 1923, 'name': 'Dependent First Name', 'type': 'text'},
#  {'id': 4301, 'name': 'Dependent Full-Time Student', 'type': 'checkbox'},
#  {'id': 1927, 'name': 'Dependent Gender', 'type': 'gender'},
#  {'id': 1935, 'name': 'Dependent Home Phone', 'type': 'phone'},
#  {'id': 1924, 'name': 'Dependent Last Name', 'type': 'text'},
#  {'id': 1925, 'name': 'Dependent Middle Name', 'type': 'text'},
#  {'id': 1926, 'name': 'Dependent Relationship', 'type': 'relationship'},
#  {'id': 1933, 'name': 'Dependent SSN', 'type': 'ssn'},
#  {'id': 1932, 'name': 'Dependent State', 'type': 'state'},
#  {'id': 1929, 'name': 'Dependent Street 1', 'type': 'text'},
#  {'id': 1930, 'name': 'Dependent Street 2', 'type': 'text'},
#  {'id': 4300, 'name': 'Dependent US Citizen', 'type': 'checkbox'},
#  {'id': 1934, 'name': 'Dependent ZIP', 'type': 'text'},
#  {'id': 4610, 'name': 'Devolution Date', 'type': 'date'},
#  {'id': 4593, 'name': 'DevSavant Teamlead', 'type': 'list'},
#  {'id': 4594, 'name': 'DevSavant Techlead', 'type': 'list'},
#  {'id': 1355, 'name': 'Division', 'type': 'list', 'alias': 'division'},
#  {'id': '4525.8',
#   'name': 'Domestic calamity leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4525.6',
#   'name': 'Domestic calamity leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4525.3',
#   'name': 'Domestic calamity leave - Available Balance',
#   'type': 'int'},
#  {'id': '4525.7',
#   'name': 'Domestic calamity leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4525.5',
#   'name': 'Domestic calamity leave - Days scheduled',
#   'type': 'int'},
#  {'id': '4525.4',
#   'name': 'Domestic calamity leave - Days taken (YTD)',
#   'type': 'int'},
#  {'id': '4525.2', 'name': 'Domestic calamity leave - Policy', 'type': 'text'},
#  {'id': 4525,
#   'name': 'Domestic calamity leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 4578, 'name': 'Effective Date', 'type': 'date'},
#  {'id': 4601, 'name': 'Effective Date', 'type': 'date'},
#  {'id': 4617, 'name': 'Effective Date', 'type': 'date'},
#  {'id': 4621, 'name': 'Effective Date', 'type': 'date'},
#  {'id': 4628, 'name': 'Effective Date', 'type': 'date'},
#  {'id': 4315, 'name': 'Eligible For Re-hire', 'type': 'list'},
#  {'id': 692, 'name': 'Emergency Contact City', 'type': 'text'},
#  {'id': 3993, 'name': 'Emergency Contact Country', 'type': 'country'},
#  {'id': 2123, 'name': 'Emergency Contact Email', 'type': 'email'},
#  {'id': 159, 'name': 'Emergency Contact Home Phone', 'type': 'phone'},
#  {'id': 693, 'name': 'Emergency Contact Mobile Phone', 'type': 'phone'},
#  {'id': 158, 'name': 'Emergency Contact Name', 'type': 'text'},
#  {'id': 4289, 'name': 'Emergency Contact Primary', 'type': 'checkbox'},
#  {'id': 160, 'name': 'Emergency Contact Relationship', 'type': 'list'},
#  {'id': 4299, 'name': 'Emergency Contacts', 'type': 'employee_contacts'},
#  {'id': 690, 'name': 'Emergency Contact State', 'type': 'state'},
#  {'id': 691, 'name': 'Emergency Contact Street 1', 'type': 'text'},
#  {'id': 2124, 'name': 'Emergency Contact Street 2', 'type': 'text'},
#  {'id': 4063, 'name': 'Emergency Contact Work Ext', 'type': 'text'},
#  {'id': 4044, 'name': 'Emergency Contact Work Phone', 'type': 'phone'},
#  {'id': 689, 'name': 'Emergency Contact ZIP Code', 'type': 'text'},
#  {'id': 636,
#   'name': 'Employee #',
#   'type': 'employee_number',
#   'alias': 'employeeNumber'},
#  {'id': 4298, 'name': 'Employee Education: End Date', 'type': 'date'},
#  {'id': 4297, 'name': 'Employee Education: Start Date', 'type': 'date'},
#  {'id': 16,
#   'name': 'Employment Status',
#   'type': 'list',
#   'alias': 'employmentHistoryStatus'},
#  {'id': '16.1',
#   'name': 'Employment Status - FTE',
#   'type': 'list',
#   'alias': 'employmentHistoryStatus'},
#  {'id': 4302,
#   'name': 'Employment Status: ACA Full-Time',
#   'type': 'aca_status',
#   'alias': 'acaStatus'},
#  {'id': 1936,
#   'name': 'Employment Status: Date',
#   'type': 'date',
#   'alias': 'employeeStatusDate'},
#  {'id': 4046, 'name': 'Employment status comments', 'type': 'textarea'},
#  {'id': '4487.4', 'name': 'English Lessons - Company pays', 'type': 'text'},
#  {'id': '4487.7',
#   'name': 'English Lessons - Company pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': '4487.2',
#   'name': 'English Lessons - Coverage',
#   'type': 'employee_new_benefit_coverage_type'},
#  {'id': '4487.1', 'name': 'English Lessons - Effective date', 'type': 'date'},
#  {'id': '4487.5',
#   'name': 'English Lessons - Eligibility date',
#   'type': 'date'},
#  {'id': '4487.3', 'name': 'English Lessons - Employee pays', 'type': 'text'},
#  {'id': '4487.6',
#   'name': 'English Lessons - Employee pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': 4487,
#   'name': 'English Lessons - Status',
#   'type': 'new_benefit_status'},
#  {'id': 4629, 'name': 'Entidad Medicina Prepagada', 'type': 'list'},
#  {'id': 4625, 'name': 'EPS', 'type': 'list'},
#  {'id': 4173, 'name': 'Expiration', 'type': 'date'},
#  {'id': 4057,
#   'name': 'Facebook URL',
#   'type': 'contact_url',
#   'alias': 'facebook'},
#  {'id': 1, 'name': 'First Name', 'type': 'text', 'alias': 'firstName'},
#  {'id': 4585, 'name': 'Flexibility Scheme', 'type': 'text'},
#  {'id': 4623, 'name': 'Fondo de Cesantías', 'type': 'list'},
#  {'id': 4624, 'name': 'Fondo de Pensión', 'type': 'list'},
#  {'id': 154, 'name': 'Gender', 'type': 'gender', 'alias': 'gender'},
#  {'id': 4296, 'name': 'GPA', 'type': 'text'},
#  {'id': 4590, 'name': 'Gross Compensation', 'type': 'currency'},
#  {'id': '4590.1',
#   'name': 'Gross Compensation - Currency code',
#   'type': 'text'},
#  {'id': 4631, 'name': 'Guide', 'type': 'textarea'},
#  {'id': 4607, 'name': 'Headhunter/ Referral', 'type': 'list'},
#  {'id': 4608, 'name': 'Headhunter Cost/ Referral Cost', 'type': 'currency'},
#  {'id': '4608.1',
#   'name': 'Headhunter Cost/ Referral Cost - Currency code',
#   'type': 'text'},
#  {'id': 3, 'name': 'Hire Date', 'type': 'date', 'alias': 'hireDate'},
#  {'id': 1357, 'name': 'Home Email', 'type': 'email', 'alias': 'homeEmail'},
#  {'id': 14, 'name': 'Home Phone', 'type': 'phone', 'alias': 'homePhone'},
#  {'id': 4576,
#   'name': 'Hours Per Pay Cycle',
#   'type': 'text',
#   'alias': 'hoursPerPayCycle'},
#  {'id': 4591, 'name': 'Housing Bonus', 'type': 'currency'},
#  {'id': '4591.1', 'name': 'Housing Bonus - Currency code', 'type': 'text'},
#  {'id': 4172, 'name': 'Issued', 'type': 'date'},
#  {'id': 4171, 'name': 'Issuing country', 'type': 'country'},
#  {'id': 4396, 'name': 'Issuing Country', 'type': 'country'},
#  {'id': 4047, 'name': 'Job Information: Date', 'type': 'date'},
#  {'id': 17, 'name': 'Job Title', 'type': 'list', 'alias': 'jobTitle'},
#  {'id': 2, 'name': 'Last Name', 'type': 'text', 'alias': 'lastName'},
#  {'id': 4058,
#   'name': 'LinkedIn URL',
#   'type': 'contact_url',
#   'alias': 'linkedIn'},
#  {'id': 18, 'name': 'Location', 'type': 'list', 'alias': 'location'},
#  {'id': 4295, 'name': 'Major/Specialization', 'type': 'text'},
#  {'id': 155,
#   'name': 'Marital Status',
#   'type': 'marital_status',
#   'alias': 'maritalStatus'},
#  {'id': '4507.8',
#   'name': 'Maternity Leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4507.6',
#   'name': 'Maternity Leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4507.3',
#   'name': 'Maternity Leave - Available Balance',
#   'type': 'int'},
#  {'id': '4507.7',
#   'name': 'Maternity Leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4507.5', 'name': 'Maternity Leave - Days scheduled', 'type': 'int'},
#  {'id': '4507.4', 'name': 'Maternity Leave - Days taken (YTD)', 'type': 'int'},
#  {'id': '4507.2', 'name': 'Maternity Leave - Policy', 'type': 'text'},
#  {'id': 4507,
#   'name': 'Maternity Leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': '4486.4', 'name': 'Medicina Prepagada - Company pays', 'type': 'text'},
#  {'id': '4486.7',
#   'name': 'Medicina Prepagada - Company pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': '4486.2',
#   'name': 'Medicina Prepagada - Coverage',
#   'type': 'employee_new_benefit_coverage_type'},
#  {'id': '4486.1',
#   'name': 'Medicina Prepagada - Effective date',
#   'type': 'date'},
#  {'id': '4486.5',
#   'name': 'Medicina Prepagada - Eligibility date',
#   'type': 'date'},
#  {'id': '4486.3',
#   'name': 'Medicina Prepagada - Employee pays',
#   'type': 'text'},
#  {'id': '4486.6',
#   'name': 'Medicina Prepagada - Employee pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': 4486,
#   'name': 'Medicina Prepagada - Status',
#   'type': 'new_benefit_status'},
#  {'id': '4632.8',
#   'name': 'Menstrual Leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4632.6',
#   'name': 'Menstrual Leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4632.3',
#   'name': 'Menstrual Leave - Available Balance',
#   'type': 'int'},
#  {'id': '4632.7',
#   'name': 'Menstrual Leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4632.5', 'name': 'Menstrual Leave - Days scheduled', 'type': 'int'},
#  {'id': '4632.4', 'name': 'Menstrual Leave - Days taken (YTD)', 'type': 'int'},
#  {'id': '4632.2', 'name': 'Menstrual Leave - Policy', 'type': 'text'},
#  {'id': 4632,
#   'name': 'Menstrual Leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 5, 'name': 'Middle Name', 'type': 'text', 'alias': 'middleName'},
#  {'id': '4522.8',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4522.6',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4522.3',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Available Balance',
#   'type': 'int'},
#  {'id': '4522.7',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4522.5',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Days scheduled',
#   'type': 'int'},
#  {'id': '4522.4',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Days taken (YTD)',
#   'type': 'int'},
#  {'id': '4522.2',
#   'name': 'Miscarriage or nonviable premature delivery  leave - Policy',
#   'type': 'text'},
#  {'id': 4522,
#   'name': 'Miscarriage or nonviable premature delivery  leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 13, 'name': 'Mobile Phone', 'type': 'phone', 'alias': 'mobilePhone'},
#  {'id': 4488,
#   'name': 'National ID #',
#   'type': 'text',
#   'alias': 'customNationalID#'},
#  {'id': 4390, 'name': 'Nationality', 'type': 'list', 'alias': 'nationality'},
#  {'id': 4582, 'name': 'Net Payments', 'type': 'currency'},
#  {'id': '4582.1', 'name': 'Net Payments - Currency code', 'type': 'text'},
#  {'id': 4174, 'name': 'Note', 'type': 'text'},
#  {'id': 4333,
#   'name': 'Original Hire Date',
#   'type': 'date',
#   'alias': 'originalHireDate'},
#  {'id': 4403,
#   'name': 'Overtime Rate',
#   'type': 'currency',
#   'alias': 'overtimeRate'},
#  {'id': '4403.1',
#   'name': 'Overtime Rate - Currency code',
#   'type': 'text',
#   'alias': 'overtimeRate'},
#  {'id': 4042, 'name': 'Overtime Status', 'type': 'exempt', 'alias': 'exempt'},
#  {'id': 4330, 'name': 'Paid per', 'type': 'paid_per', 'alias': 'payPer'},
#  {'id': 4393, 'name': 'Passport: Expiry Date', 'type': 'passport_expiry'},
#  {'id': 4392, 'name': 'Passport: Issued Date', 'type': 'passport_issued'},
#  {'id': 4391, 'name': 'Passport Number', 'type': 'passport_number'},
#  {'id': '4510.8',
#   'name': 'Paternity Leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4510.6',
#   'name': 'Paternity Leave - Adjustments (YTD)',
#   'type': 'int'},
#  {'id': '4510.3',
#   'name': 'Paternity Leave - Available Balance',
#   'type': 'int'},
#  {'id': '4510.7',
#   'name': 'Paternity Leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4510.5', 'name': 'Paternity Leave - Days scheduled', 'type': 'int'},
#  {'id': '4510.4', 'name': 'Paternity Leave - Days taken (YTD)', 'type': 'int'},
#  {'id': '4510.2', 'name': 'Paternity Leave - Policy', 'type': 'text'},
#  {'id': 4510,
#   'name': 'Paternity Leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 19, 'name': 'Pay rate', 'type': 'currency', 'alias': 'payRate'},
#  {'id': '19.1',
#   'name': 'Pay rate - Currency code',
#   'type': 'text',
#   'alias': 'payRate'},
#  {'id': 4605, 'name': 'Payroll Cost', 'type': 'currency'},
#  {'id': '4605.1', 'name': 'Payroll Cost - Currency code', 'type': 'text'},
#  {'id': 4331,
#   'type': 'pay_period',
#   'deprecated': True,
#   'name': 'Pay Period',
#   'alias': 'payPeriod'},
#  {'id': 4386, 'name': 'Pay Schedule', 'type': 'list', 'alias': 'paySchedule'},
#  {'id': 4579, 'name': 'Pay Schedule', 'type': 'list'},
#  {'id': 156, 'name': 'Pay type', 'type': 'pay_type', 'alias': 'payType'},
#  {'id': 1358,
#   'type': 'text',
#   'deprecated': True,
#   'name': 'Nickname',
#   'alias': 'nickname'},
#  {'id': 1358,
#   'name': 'Preferred Name',
#   'type': 'text',
#   'alias': 'preferredName'},
#  {'id': '4597.4', 'name': 'Prepagada - Company pays', 'type': 'text'},
#  {'id': '4597.7',
#   'name': 'Prepagada - Company pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': '4597.2',
#   'name': 'Prepagada - Coverage',
#   'type': 'employee_new_benefit_coverage_type'},
#  {'id': '4597.1', 'name': 'Prepagada - Effective date', 'type': 'date'},
#  {'id': '4597.5', 'name': 'Prepagada - Eligibility date', 'type': 'date'},
#  {'id': '4597.3', 'name': 'Prepagada - Employee pays', 'type': 'text'},
#  {'id': '4597.6',
#   'name': 'Prepagada - Employee pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': 4597, 'name': 'Prepagada - Status', 'type': 'new_benefit_status'},
#  {'id': 4595, 'name': 'Project', 'type': 'list'},
#  {'id': '4604.4', 'name': 'Prueba Prepagada - Company pays', 'type': 'text'},
#  {'id': '4604.7',
#   'name': 'Prueba Prepagada - Company pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': '4604.2',
#   'name': 'Prueba Prepagada - Coverage',
#   'type': 'employee_new_benefit_coverage_type'},
#  {'id': '4604.1', 'name': 'Prueba Prepagada - Effective date', 'type': 'date'},
#  {'id': '4604.5',
#   'name': 'Prueba Prepagada - Eligibility date',
#   'type': 'date'},
#  {'id': '4604.3', 'name': 'Prueba Prepagada - Employee pays', 'type': 'text'},
#  {'id': '4604.6',
#   'name': 'Prueba Prepagada - Employee pays - Currency code',
#   'type': 'new_benefit'},
#  {'id': 4604,
#   'name': 'Prueba Prepagada - Status',
#   'type': 'new_benefit_status'},
#  {'id': 4609, 'name': 'Referred from', 'type': 'text'},
#  {'id': 91, 'name': 'Reporting to', 'type': 'employee'},
#  {'id': 4463, 'name': 'Routing Number', 'type': 'text'},
#  {'id': 4583, 'name': 'Salary', 'type': 'currency'},
#  {'id': '4583.1', 'name': 'Salary - Currency code', 'type': 'text'},
#  {'id': 4587, 'name': 'Salary Type', 'type': 'list'},
#  {'id': 1610, 'name': 'Self-service access', 'type': 'employee_access'},
#  {'id': 4618, 'name': 'Seniority', 'type': 'list'},
#  {'id': 4412, 'name': 'Shirt Size', 'type': 'list', 'alias': 'shirtSize'},
#  {'id': '4513.8',
#   'name': 'Sick Leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4513.6', 'name': 'Sick Leave - Adjustments (YTD)', 'type': 'int'},
#  {'id': '4513.3', 'name': 'Sick Leave - Available Balance', 'type': 'int'},
#  {'id': '4513.7',
#   'name': 'Sick Leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4513.5', 'name': 'Sick Leave - Days scheduled', 'type': 'int'},
#  {'id': '4513.4', 'name': 'Sick Leave - Days taken (YTD)', 'type': 'int'},
#  {'id': '4513.2', 'name': 'Sick Leave - Policy', 'type': 'text'},
#  {'id': 4513,
#   'name': 'Sick Leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 7, 'name': 'SSN', 'type': 'ssn', 'alias': 'ssn'},
#  {'id': 4569, 'name': 'Start Date', 'type': 'date'},
#  {'id': 11, 'name': 'State', 'type': 'state', 'alias': 'state'},
#  {'id': 387,
#   'type': 'status',
#   'deprecated': True,
#   'name': 'Employment Status',
#   'alias': 'employmentStatus'},
#  {'id': 387, 'name': 'Status', 'type': 'status', 'alias': 'status'},
#  {'id': 4619, 'name': 'Sublevel', 'type': 'list'},
#  {'id': 4598, 'name': 'Swift Code', 'type': 'text'},
#  {'id': 4314, 'name': 'Termination Reason', 'type': 'list'},
#  {'id': 4313, 'name': 'Termination Type', 'type': 'list'},
#  {'id': 4630, 'name': 'Tipo de Plan', 'type': 'list'},
#  {'id': 4614, 'name': 'Tool', 'type': 'list'},
#  {'id': 4612, 'name': 'Tool Code', 'type': 'list'},
#  {'id': 4615, 'name': 'Tool Information', 'type': 'textarea'},
#  {'id': 4635, 'name': 'Tool Status', 'type': 'list'},
#  {'id': 4056,
#   'name': 'Twitter Feed',
#   'type': 'twitter_handle',
#   'alias': 'twitterFeed'},
#  {'id': '4519.8',
#   'name': 'Unpaid leave - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4519.6', 'name': 'Unpaid leave - Adjustments (YTD)', 'type': 'int'},
#  {'id': '4519.3', 'name': 'Unpaid leave - Available Balance', 'type': 'int'},
#  {'id': '4519.7',
#   'name': 'Unpaid leave - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4519.5', 'name': 'Unpaid leave - Days scheduled', 'type': 'int'},
#  {'id': '4519.4', 'name': 'Unpaid leave - Days taken (YTD)', 'type': 'int'},
#  {'id': '4519.2', 'name': 'Unpaid leave - Policy', 'type': 'text'},
#  {'id': 4519,
#   'name': 'Unpaid leave - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': '4482.8',
#   'name': 'Vacations - Accrual Start Date',
#   'type': 'time_off_type'},
#  {'id': '4482.6', 'name': 'Vacations - Adjustments (YTD)', 'type': 'int'},
#  {'id': '4482.3', 'name': 'Vacations - Available Balance', 'type': 'int'},
#  {'id': '4482.7',
#   'name': 'Vacations - Current balance',
#   'type': 'time_off_type'},
#  {'id': '4482.5', 'name': 'Vacations - Days scheduled', 'type': 'int'},
#  {'id': '4482.4', 'name': 'Vacations - Days taken (YTD)', 'type': 'int'},
#  {'id': '4482.2', 'name': 'Vacations - Policy', 'type': 'text'},
#  {'id': 4482,
#   'name': 'Vacations - Policy Assigned',
#   'type': 'time_off_type_exists'},
#  {'id': 4506,
#   'name': 'Vacations  policy - Assigned',
#   'type': 'time_off_policy_exists'},
#  {'id': '4506.1', 'name': 'Vacations  policy - Started on', 'type': 'date'},
#  {'id': 4170, 'name': 'Visa', 'type': 'list'},
#  {'id': 4169, 'name': 'Visa:Date', 'type': 'date'},
#  {'id': 15, 'name': 'Work Email', 'type': 'email', 'alias': 'workEmail'},
#  {'id': 635,
#   'name': 'Work Ext.',
#   'type': 'text',
#   'alias': 'workPhoneExtension'},
#  {'id': 634, 'name': 'Work Phone', 'type': 'phone', 'alias': 'workPhone'},
#  {'id': 12, 'name': 'Zip Code', 'type': 'text', 'alias': 'zipcode'},
#  {'id': -38,
#   'name': 'Termination Date',
#   'type': 'date',
#   'alias': 'terminationDate'}]

# %%
our_Nfields = [] # Fields with none aliases
our_Afields = [] # Fields with Aliases
for x in field:
    try:
        our_Afields.append(x['alias'])
    except:
        our_Nfields.append(x['name'])

# %%
# Create JSON file with None aliases fields
with open("fieldsWhitoutAliases.json", "w") as outfile:
    json.dump(our_Nfields, outfile)

# %% [markdown]
# ## Call Pre-created Reports

# %%
url = "https://api.bamboohr.com/api/gateway.php/devsavant/v1/reports/366?format=json&fd=no&onlyCurrent=false"
headers = {
    "Accept": "application/json",
    "authorization": authorization
}
response = requests.get(url, headers=headers)
response.json()
# Out:
# {'title': 'Report4',
#  'fields': [{'id': 'fullName2',
#    'type': 'text',
#    'name': 'Last Name, First Name'},
#   {'id': 'customClientStartDate', 'type': 'date', 'name': 'Start Date'},
#   {'id': 'customClient', 'type': 'list', 'name': 'Client'},
#   {'id': 'customProject', 'type': 'list', 'name': 'Project'},
#   {'id': 'customClientLead', 'type': 'list', 'name': 'Client Lead'},
#   {'id': 'customDevSavantTeamlead',
#    'type': 'list',
#    'name': 'DevSavant Teamlead'},
#   {'id': 'customDevSavantTechlead',
#    'type': 'list',
#    'name': 'DevSavant Techlead'},
#   {'id': 'customSeniorityfrentealcliente',
#    'type': 'list',
#    'name': 'Client Seniority'},
#   {'id': 4047, 'type': 'date', 'name': 'Job Information: Date'},
#   {'id': 'location', 'type': 'list', 'name': 'Location'},
#   {'id': 'division', 'type': 'list', 'name': 'Division'},
#   {'id': 'department', 'type': 'list', 'name': 'Department'},
#   {'id': 'jobTitle', 'type': 'list', 'name': 'Job Title'},
#   {'id': 91, 'type': 'employee', 'name': 'Reporting to'}],
#  'employees': [{'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-12-01',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Pedro Alejandro Avila Plaza',
#    'customDevSavantTechlead': 'Pedro Alejandro Avila Plaza',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-12-01',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Pedro Alejandro Avila Plaza',
#    'customDevSavantTechlead': 'Pedro Alejandro Avila Plaza',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Juan Gaviria Sierra'},
#   {'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-12-01',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Pedro Alejandro Avila Plaza',
#    'customDevSavantTechlead': 'Pedro Alejandro Avila Plaza',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2021-08-02',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Pedro Avila Plaza'},
#   {'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-08-02',
#    'customClient': 'Operational Support',
#    'customProject': None,
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Valentina Tobon Restrepo',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-08-02',
#    'customClient': 'Operational Support',
#    'customProject': None,
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Valentina Tobon Restrepo',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Juan Gaviria Sierra'},
#   {'id': '242',
#    'fullName2': 'Acosta Celis, Juan',
#    'customClientStartDate': '2021-08-02',
#    'customClient': 'Operational Support',
#    'customProject': None,
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Valentina Tobon Restrepo',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2021-08-02',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Developer Associate',
#    '91': 'Pedro Avila Plaza'},
#   {'id': '119',
#    'fullName2': 'Acosta Jimenez, Alexander',
#    'customClientStartDate': '2020-02-26',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '119',
#    'fullName2': 'Acosta Jimenez, Alexander',
#    'customClientStartDate': '2020-02-26',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '119',
#    'fullName2': 'Acosta Jimenez, Alexander',
#    'customClientStartDate': '2020-02-26',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2021-06-08',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '119',
#    'fullName2': 'Acosta Jimenez, Alexander',
#    'customClientStartDate': '2020-02-26',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2020-02-26',
#    'location': 'Jaya Company',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Matt Dunn'},
#   {'id': '225',
#    'fullName2': 'Acosta Martinez, Josue',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Talent Acquisition',
#    'department': 'Talent Acquisition',
#    'jobTitle': 'Senior IT Recruiter',
#    '91': 'Sebastian Blandon'},
#   {'id': '225',
#    'fullName2': 'Acosta Martinez, Josue',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-01',
#    'location': 'DevSavantCo',
#    'division': 'HR & Recruitment',
#    'department': 'Human Resources',
#    'jobTitle': 'Senior IT Recruiter',
#    '91': 'Nathalia Eraso Guerrero'},
#   {'id': '143',
#    'fullName2': 'Acuña Granados, Daniela',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Project Manager / Office Manager',
#    '91': 'Nury Alejandra Aguilar Rodriguez'},
#   {'id': '143',
#    'fullName2': 'Acuña Granados, Daniela',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-01-24',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Lead Data Research Analyst',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '143',
#    'fullName2': 'Acuña Granados, Daniela',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-14',
#    'location': 'DevSavantCo',
#    'division': 'Data Analyst',
#    'department': 'Outsourcing',
#    'jobTitle': 'Lead Data Research Analyst',
#    '91': None},
#   {'id': '143',
#    'fullName2': 'Acuña Granados, Daniela',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2020-09-01',
#    'location': 'DevSavantCo',
#    'division': 'Data Analyst',
#    'department': 'Outsourcing',
#    'jobTitle': 'Lead Data Research Analyst',
#    '91': 'Daniel Peña Ronderos'},
#   {'id': '328',
#    'fullName2': 'Adanza, Roman',
#    'customClientStartDate': '2022-02-23',
#    'customClient': 'RevSavant',
#    'customProject': 'Revsavant',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Alex Hollander',
#    'customDevSavantTechlead': 'Alex Hollander',
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-02-23',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Graphic Designer',
#    '91': 'Alex Chiel Hollander'},
#   {'id': '263',
#    'fullName2': 'Agámez Licha, Álvaro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-10-18',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Full Stack Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '324',
#    'fullName2': 'Aguilar Rodriguez, Nury Alejandra',
#    'customClientStartDate': '2022-02-23',
#    'customClient': 'DevSavant',
#    'customProject': 'Devsavant',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Amalia Lopera',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Semi Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Project Manager',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '324',
#    'fullName2': 'Aguilar Rodriguez, Nury Alejandra',
#    'customClientStartDate': '2022-02-23',
#    'customClient': 'DevSavant',
#    'customProject': 'Devsavant',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Amalia Lopera',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Semi Senior',
#    '4047': '2022-02-23',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Project Manager',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '293',
#    'fullName2': 'Aguirre Campi, Andres',
#    'customClientStartDate': '2021-12-13',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-12',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '293',
#    'fullName2': 'Aguirre Campi, Andres',
#    'customClientStartDate': '2021-12-13',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '293',
#    'fullName2': 'Aguirre Campi, Andres',
#    'customClientStartDate': '2021-12-13',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-12-13',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '217',
#    'fullName2': 'Ahumada Gomez, Gregory',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-04-20',
#    'location': 'DevSavant Inc',
#    'division': 'Data Analyst',
#    'department': 'Outsourcing',
#    'jobTitle': 'Data Research Analyst',
#    '91': 'Daniela Acuña Granados'},
#   {'id': '162',
#    'fullName2': 'Alvarez Alvarado, Jaime',
#    'customClientStartDate': '2021-02-15',
#    'customClient': 'Onfleet',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-10-13',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Junior Software Developer',
#    '91': 'Ludwig David Zuluaga Botero'},
#   {'id': '162',
#    'fullName2': 'Alvarez Alvarado, Jaime',
#    'customClientStartDate': '2021-02-15',
#    'customClient': 'Onfleet',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Junior Software Developer',
#    '91': 'David Garcia Maldonado'},
#   {'id': '162',
#    'fullName2': 'Alvarez Alvarado, Jaime',
#    'customClientStartDate': '2021-02-15',
#    'customClient': 'Onfleet',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2021-02-15',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Junior Software Developer',
#    '91': 'David Garcia Maldonado'},
#   {'id': '181',
#    'fullName2': 'Álvarez Arango, Laura',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Accounting Lead',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '181',
#    'fullName2': 'Álvarez Arango, Laura',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-14',
#    'location': 'DevSavantCo',
#    'division': None,
#    'department': 'Admin and Finance',
#    'jobTitle': 'Junior Accountant',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '291',
#    'fullName2': 'Álvarez Valencia, Ronal',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-12-01',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Business Operations Analyst',
#    '91': 'Camilo Correa Colorado'},
#   {'id': '291',
#    'fullName2': 'Álvarez Valencia, Ronal',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Documentation Support Officer',
#    '91': 'Camilo Correa Colorado'},
#   {'id': '291',
#    'fullName2': 'Álvarez Valencia, Ronal',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-12-09',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Documentation Support Officer',
#    '91': 'Camilo Correa Colorado'},
#   {'id': '199',
#    'fullName2': 'Alvarez, Pedro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2019-10-28',
#    'location': 'Jaya Company',
#    'division': 'Cross Border',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '274',
#    'fullName2': 'Anriquez, Carlos',
#    'customClientStartDate': '2021-11-16',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Pedro Alejandro Avila Plaza',
#    'customDevSavantTechlead': 'Pedro Alejandro Avila Plaza',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior React Developer',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '274',
#    'fullName2': 'Anriquez, Carlos',
#    'customClientStartDate': '2021-11-16',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Pedro Alejandro Avila Plaza',
#    'customDevSavantTechlead': 'Pedro Alejandro Avila Plaza',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2021-11-16',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior React Developer',
#    '91': 'Pedro Avila Plaza'},
#   {'id': '399',
#    'fullName2': 'Antelo Reñones, Paula',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-06-15',
#    'location': 'DevSavant Inc',
#    'division': 'Management',
#    'department': 'General Management',
#    'jobTitle': 'Accelerator Officer',
#    '91': 'Daniel Peña Ronderos'},
#   {'id': '364',
#    'fullName2': 'Antequera Prias, Angelica',
#    'customClientStartDate': '2022-04-18',
#    'customClient': 'DevSavant',
#    'customProject': 'Devsavant',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juliana Caballero',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'General Management',
#    'jobTitle': 'Business Analyst',
#    '91': 'Juliana Caballero'},
#   {'id': '364',
#    'fullName2': 'Antequera Prias, Angelica',
#    'customClientStartDate': '2022-04-18',
#    'customClient': 'DevSavant',
#    'customProject': 'Devsavant',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juliana Caballero',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-04-18',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'General Management',
#    'jobTitle': 'Business Analyst',
#    '91': 'Juliana Caballero'},
#   {'id': '331',
#    'fullName2': 'Aponte Agudelo, Albert',
#    'customClientStartDate': '2022-03-07',
#    'customClient': 'Impartner',
#    'customProject': 'General Support',
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': 'Angela Maria Arango Amaya',
#    'customDevSavantTechlead': 'Angela Maria Arango Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation',
#    '91': 'Angela Arango Amaya'},
#   {'id': '331',
#    'fullName2': 'Aponte Agudelo, Albert',
#    'customClientStartDate': '2022-03-07',
#    'customClient': 'Impartner',
#    'customProject': 'General Support',
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': 'Angela Maria Arango Amaya',
#    'customDevSavantTechlead': 'Angela Maria Arango Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation',
#    '91': 'Angela Arango Amaya'},
#   {'id': '331',
#    'fullName2': 'Aponte Agudelo, Albert',
#    'customClientStartDate': '2022-03-07',
#    'customClient': 'Impartner',
#    'customProject': 'General Support',
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': 'Angela Maria Arango Amaya',
#    'customDevSavantTechlead': 'Angela Maria Arango Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-03-07',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation',
#    '91': 'Angela Arango Amaya'},
#   {'id': '367',
#    'fullName2': 'Arana Chavez, Laura',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-12-21',
#    'location': 'DevSavantCo',
#    'division': 'Data Analyst',
#    'department': 'Operations',
#    'jobTitle': 'Research Analyst',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '367',
#    'fullName2': 'Arana Chavez, Laura',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Talent Acquisition',
#    'department': 'Talent Acquisition',
#    'jobTitle': 'IT Sourcing Analyst',
#    '91': 'Maria Cuartas Toro'},
#   {'id': '367',
#    'fullName2': 'Arana Chavez, Laura',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-04-20',
#    'location': 'DevSavantCo',
#    'division': 'Talent Acquisition',
#    'department': 'Human Resources',
#    'jobTitle': 'IT Sourcing Analyst',
#    '91': 'Maria Cuartas Toro'},
#   {'id': '341',
#    'fullName2': 'Arango Amaya, Angela',
#    'customClientStartDate': '2022-03-09',
#    'customClient': 'Impartner',
#    'customProject': 'Integrations',
#    'customClientLead': 'Tom Mayfield',
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-03-09',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Project Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '176',
#    'fullName2': 'Arango Lopez, Julian',
#    'customClientStartDate': '2019-08-05',
#    'customClient': 'XBS',
#    'customProject': 'QA Frameworks',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juan Camilo Mejia Zuluaga',
#    'customDevSavantTechlead': 'Juan Camilo Mejia',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '176',
#    'fullName2': 'Arango Lopez, Julian',
#    'customClientStartDate': '2019-08-05',
#    'customClient': 'XBS',
#    'customProject': 'QA Frameworks',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juan Camilo Mejia Zuluaga',
#    'customDevSavantTechlead': 'Juan Camilo Mejia',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '176',
#    'fullName2': 'Arango Lopez, Julian',
#    'customClientStartDate': '2019-08-05',
#    'customClient': 'XBS',
#    'customProject': 'QA Frameworks',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juan Camilo Mejia Zuluaga',
#    'customDevSavantTechlead': 'Juan Camilo Mejia',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '176',
#    'fullName2': 'Arango Lopez, Julian',
#    'customClientStartDate': '2019-08-05',
#    'customClient': 'XBS',
#    'customProject': 'QA Frameworks',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juan Camilo Mejia Zuluaga',
#    'customDevSavantTechlead': 'Juan Camilo Mejia',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '176',
#    'fullName2': 'Arango Lopez, Julian',
#    'customClientStartDate': '2019-08-05',
#    'customClient': 'XBS',
#    'customProject': 'QA Frameworks',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Juan Camilo Mejia Zuluaga',
#    'customDevSavantTechlead': 'Juan Camilo Mejia',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2019-08-05',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Mid Level Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '374',
#    'fullName2': 'Araujo, Edgar Gante',
#    'customClientStartDate': '2022-05-09',
#    'customClient': 'Fulcrum',
#    'customProject': None,
#    'customClientLead': 'Chris Loiuse',
#    'customDevSavantTeamlead': 'Juan Jose Gaviria Sierra',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-10-12',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'IOS Developer',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '374',
#    'fullName2': 'Araujo, Edgar Gante',
#    'customClientStartDate': '2022-05-09',
#    'customClient': 'Fulcrum',
#    'customProject': None,
#    'customClientLead': 'Chris Loiuse',
#    'customDevSavantTeamlead': 'Juan Jose Gaviria Sierra',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'IOS Developer',
#    '91': 'Juan Gaviria Sierra'},
#   {'id': '374',
#    'fullName2': 'Araujo, Edgar Gante',
#    'customClientStartDate': '2022-05-09',
#    'customClient': 'Fulcrum',
#    'customProject': None,
#    'customClientLead': 'Chris Loiuse',
#    'customDevSavantTeamlead': 'Juan Jose Gaviria Sierra',
#    'customDevSavantTechlead': 'Juan Jose Gaviria Sierra',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-05-09',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'IOS Developer',
#    '91': 'Juan Gaviria Sierra'},
#   {'id': '382',
#    'fullName2': 'Arbelaez Garcia, Ricardo',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Business Operations Specialist',
#    '91': 'Camilo Correa Colorado'},
#   {'id': '382',
#    'fullName2': 'Arbelaez Garcia, Ricardo',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-06-01',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Business Operations Specialist',
#    '91': 'Camilo Correa Colorado'},
#   {'id': '380',
#    'fullName2': 'Arbelo Figueroa, Leonardo',
#    'customClientStartDate': '2022-05-15',
#    'customClient': 'Conversica',
#    'customProject': 'QA',
#    'customClientLead': 'Rob Fulwell',
#    'customDevSavantTeamlead': 'David Garcia Maldonado',
#    'customDevSavantTechlead': 'David Garcia Maldonado',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-10-13',
#    'location': 'DevSavant Inc',
#    'division': 'Quality Assurance',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation Engineer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '380',
#    'fullName2': 'Arbelo Figueroa, Leonardo',
#    'customClientStartDate': '2022-05-15',
#    'customClient': 'Conversica',
#    'customProject': 'QA',
#    'customClientLead': 'Rob Fulwell',
#    'customDevSavantTeamlead': 'David Garcia Maldonado',
#    'customDevSavantTechlead': 'David Garcia Maldonado',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavant Inc',
#    'division': 'Quality Assurance',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation Engineer',
#    '91': 'David Garcia Maldonado'},
#   {'id': '380',
#    'fullName2': 'Arbelo Figueroa, Leonardo',
#    'customClientStartDate': '2022-05-15',
#    'customClient': 'Conversica',
#    'customProject': 'QA',
#    'customClientLead': 'Rob Fulwell',
#    'customDevSavantTeamlead': 'David Garcia Maldonado',
#    'customDevSavantTechlead': 'David Garcia Maldonado',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-05-16',
#    'location': 'DevSavant Inc',
#    'division': 'Quality Assurance',
#    'department': 'Operations',
#    'jobTitle': 'QA Automation Engineer',
#    '91': 'David Garcia Maldonado'},
#   {'id': '214',
#    'fullName2': 'Ardon Zeledon, Jorge',
#    'customClientStartDate': '2021-05-03',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Juan Jose Gaviria Sierra',
#    'customDevSavantTechlead': 'Kara Fox',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Full Stack Developer',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '214',
#    'fullName2': 'Ardon Zeledon, Jorge',
#    'customClientStartDate': '2021-05-03',
#    'customClient': 'Fulcrum',
#    'customProject': 'Engineering',
#    'customClientLead': 'Kara Fox',
#    'customDevSavantTeamlead': 'Juan Jose Gaviria Sierra',
#    'customDevSavantTechlead': 'Kara Fox',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2021-04-04',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Full Stack Developer',
#    '91': 'Juan Gaviria Sierra'},
#   {'id': '236',
#    'fullName2': 'Arenas Rodriguez, Oscar',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Frontend Developer',
#    '91': 'Valerie Dean Salcedo'},
#   {'id': '236',
#    'fullName2': 'Arenas Rodriguez, Oscar',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Frontend Developer',
#    '91': 'Valerie Dean Salcedo'},
#   {'id': '236',
#    'fullName2': 'Arenas Rodriguez, Oscar',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-28',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Frontend Developer',
#    '91': 'Luis Rivero Cruz'},
#   {'id': '413',
#    'fullName2': 'Arevalo Forero, Eduardo Florentino',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-08',
#    'location': 'DevSavantCo',
#    'division': 'UX - UI',
#    'department': 'Operations',
#    'jobTitle': 'Aprendiz de Software',
#    '91': 'David Lema Escobar'},
#   {'id': '438',
#    'fullName2': 'Arevalo Goldfeld, Leandro Eliseo',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-11-21',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Javascript Frontend Developer',
#    '91': 'Sebastian Blandon'},
#   {'id': '156',
#    'fullName2': 'Arias Arias, Eylen',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '156',
#    'fullName2': 'Arias Arias, Eylen',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2019-09-13',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '184',
#    'fullName2': 'Arias Arias, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '184',
#    'fullName2': 'Arias Arias, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '184',
#    'fullName2': 'Arias Arias, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2020-12-01',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '305',
#    'fullName2': 'Asto Carrasco, Arturo Neil',
#    'customClientStartDate': '2022-01-03',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Semi Senior',
#    '4047': '2022-10-12',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '305',
#    'fullName2': 'Asto Carrasco, Arturo Neil',
#    'customClientStartDate': '2022-01-03',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Semi Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer.',
#    '91': 'Angela Arango Amaya'},
#   {'id': '305',
#    'fullName2': 'Asto Carrasco, Arturo Neil',
#    'customClientStartDate': '2022-01-03',
#    'customClient': 'Impartner',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Semi Senior',
#    '4047': '2022-01-03',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer.',
#    '91': 'Angela Arango Amaya'},
#   {'id': '150',
#    'fullName2': 'Avila Franco, Diana',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Human Resources',
#    'jobTitle': 'Employee Specialist',
#    '91': 'Mariana Bedoya Cuartas'},
#   {'id': '150',
#    'fullName2': 'Avila Franco, Diana',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-06-23',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Employee Specialist',
#    '91': 'Daniela Hernandéz Madriñan'},
#   {'id': '150',
#    'fullName2': 'Avila Franco, Diana',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-03-24',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Employee Specialist',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '150',
#    'fullName2': 'Avila Franco, Diana',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-08-02',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Administrative Officer',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '150',
#    'fullName2': 'Avila Franco, Diana',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2020-09-14',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Asistente Contable y Administrativo',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '200',
#    'fullName2': 'Avila Plaza, Pedro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-12',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Associate Software Engineering Manager',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '200',
#    'fullName2': 'Avila Plaza, Pedro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-07-01',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Associate Software Engineering Manager',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '200',
#    'fullName2': 'Avila Plaza, Pedro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-08-02',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Tech Lead Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '200',
#    'fullName2': 'Avila Plaza, Pedro',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-01-04',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Senior Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '381',
#    'fullName2': 'Ayala Rico, Juan',
#    'customClientStartDate': '2022-05-11',
#    'customClient': 'Operational Support',
#    'customProject': 'Fulcrum',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Valentina Tobon Restrepo',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'Operations',
#    'jobTitle': 'Project Manager',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '381',
#    'fullName2': 'Ayala Rico, Juan',
#    'customClientStartDate': '2022-05-11',
#    'customClient': 'Operational Support',
#    'customProject': 'Fulcrum',
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Valentina Tobon Restrepo',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-05-11',
#    'location': 'DevSavantCo',
#    'division': 'Project Manager',
#    'department': 'Operations',
#    'jobTitle': 'Project Manager',
#    '91': 'Valentina Tobon Restrepo'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Alejandro Heredia'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Alejandro Heredia'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Alejandro Heredia'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Alejandro Heredia'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-05',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Alejandro Heredia'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-30',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Angela Arango Amaya'},
#   {'id': '201',
#    'fullName2': 'Baron Castro, Rafael',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2020-12-01',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Impartner Software Developer',
#    '91': 'Saul Celis Valbuena'},
#   {'id': '352',
#    'fullName2': 'Barrios Monroy, Maria',
#    'customClientStartDate': '2022-04-04',
#    'customClient': 'DevSavant',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Maria Adelaida Cuartas',
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-04-04',
#    'location': 'DevSavantCo',
#    'division': 'Talent Acquisition',
#    'department': 'Human Resources',
#    'jobTitle': 'IT Sourcing Analyst',
#    '91': 'Maria Cuartas Toro'},
#   {'id': '255',
#    'fullName2': 'Barrios Perez, Marelbi',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Staff',
#    'department': 'Admin and Finance',
# ...
#    'customDevSavantTechlead': 'Saul Leonardo Celis Valbuena',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-04-27',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Engineer',
#    '91': 'Saul Celis Valbuena'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': 'Intelepeer',
#    'customProject': 'Redica',
#    'customClientLead': 'Alex Kouznetsov',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': 'Intelepeer',
#    'customProject': 'Redica',
#    'customClientLead': 'Alex Kouznetsov',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': 'Intelepeer',
#    'customProject': 'Redica',
#    'customClientLead': 'Alex Kouznetsov',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': 'Intelepeer',
#    'customProject': 'Redica',
#    'customClientLead': 'Alex Kouznetsov',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-03-16',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '343',
#    'fullName2': 'Villamizar Torres, Marco',
#    'customClientStartDate': '2022-03-16',
#    'customClient': 'Intelepeer',
#    'customProject': 'Redica',
#    'customClientLead': 'Alex Kouznetsov',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Mid',
#    '4047': '2022-03-16',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '415',
#    'fullName2': 'Villarreal  Zuñiga, Karilys',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-08-22',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Accounting & Taxes Lead',
#    '91': 'Amalia Lopera Correa'},
#   {'id': '155',
#    'fullName2': 'Viveros Suarez, Erika',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-12-05',
#    'location': 'DevSavant Inc',
#    'division': 'Data Analyst',
#    'department': 'Operations',
#    'jobTitle': 'Research Analyst',
#    '91': 'Ludwig David Zuluaga Botero'},
#   {'id': '155',
#    'fullName2': 'Viveros Suarez, Erika',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-14',
#    'location': 'DevSavant Inc',
#    'division': 'Data Analyst',
#    'department': 'Outsourcing',
#    'jobTitle': 'Data Research Analyst',
#    '91': 'Daniela Acuña Granados'},
#   {'id': '155',
#    'fullName2': 'Viveros Suarez, Erika',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-02-15',
#    'location': 'DevSavant Inc',
#    'division': 'Data Analyst',
#    'department': 'Outsourcing',
#    'jobTitle': 'Data Research Analyst',
#    '91': 'Daniela Acuña Granados'},
#   {'id': '327',
#    'fullName2': 'Yanez Martinez, Kelly',
#    'customClientStartDate': '2022-02-21',
#    'customClient': 'DevSavant',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Staff',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Servicios Generales',
#    '91': 'Daniela Acuña Granados'},
#   {'id': '327',
#    'fullName2': 'Yanez Martinez, Kelly',
#    'customClientStartDate': '2022-02-21',
#    'customClient': 'DevSavant',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': 'Junior',
#    '4047': '2022-02-21',
#    'location': 'DevSavantCo',
#    'division': 'Staff',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Servicios Generales',
#    '91': 'Daniela Acuña Granados'},
#   {'id': '186',
#    'fullName2': 'Zafra Romero, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-06-14',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Administrative Assitant',
#    '91': 'Paola Castellanos'},
#   {'id': '186',
#    'fullName2': 'Zafra Romero, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-05-09',
#    'location': 'DevSavantCo',
#    'division': 'SavantGrowth',
#    'department': 'SavantGrowth',
#    'jobTitle': 'Administrative Assitant',
#    '91': 'Paola Castellanos'},
#   {'id': '186',
#    'fullName2': 'Zafra Romero, Maria',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-02-08',
#    'location': 'DevSavantCo',
#    'division': None,
#    'department': 'SavantGrowth',
#    'jobTitle': 'Administrative Assitant',
#    '91': 'Paola Castellanos'},
#   {'id': '277',
#    'fullName2': 'Zapata Maldonado, Mateo Santiago',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2021-11-16',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Research and Development Engineer',
#    '91': 'Sebastian Blandon'},
#   {'id': '440',
#    'fullName2': 'Zapata Munera, Daniela',
#    'customClientStartDate': None,
#    'customClient': None,
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-12-05',
#    'location': 'DevSavantCo',
#    'division': 'Administrative',
#    'department': 'Admin and Finance',
#    'jobTitle': 'Accounting Support',
#    '91': 'Karilys Villarreal  Zuñiga'},
#   {'id': '313',
#    'fullName2': 'Zion, Ezequiel',
#    'customClientStartDate': '2022-02-07',
#    'customClient': 'CDO Office',
#    'customProject': 'Ghost Coder Sebastian',
#    'customClientLead': 'XBS',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-10-13',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Sebastian Blandon'},
#   {'id': '313',
#    'fullName2': 'Zion, Ezequiel',
#    'customClientStartDate': '2022-02-07',
#    'customClient': 'CDO Office',
#    'customProject': 'Ghost Coder Sebastian',
#    'customClientLead': 'XBS',
#    'customDevSavantTeamlead': None,
#    'customDevSavantTechlead': None,
#    'customSeniorityfrentealcliente': None,
#    '4047': '2022-02-07',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Software Developer',
#    '91': 'Juan Mejia Zuluaga'},
#   {'id': '337',
#    'fullName2': 'Zuluaga Botero, Ludwig David',
#    'customClientStartDate': '2022-03-22',
#    'customClient': 'CDO Office',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Delivery Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '337',
#    'fullName2': 'Zuluaga Botero, Ludwig David',
#    'customClientStartDate': '2022-03-22',
#    'customClient': 'CDO Office',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Delivery Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '337',
#    'fullName2': 'Zuluaga Botero, Ludwig David',
#    'customClientStartDate': '2022-03-22',
#    'customClient': 'CDO Office',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Delivery Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '337',
#    'fullName2': 'Zuluaga Botero, Ludwig David',
#    'customClientStartDate': '2022-03-22',
#    'customClient': 'CDO Office',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Delivery Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '337',
#    'fullName2': 'Zuluaga Botero, Ludwig David',
#    'customClientStartDate': '2022-03-22',
#    'customClient': 'CDO Office',
#    'customProject': None,
#    'customClientLead': None,
#    'customDevSavantTeamlead': 'Sebastian Blandon',
#    'customDevSavantTechlead': 'Sebastian Blandon',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-03-22',
#    'location': 'DevSavantCo',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Delivery Manager',
#    '91': 'Sebastian Blandon'},
#   {'id': '397',
#    'fullName2': 'Zuluaga Suarez, Daniel',
#    'customClientStartDate': '2022-06-29',
#    'customClient': 'Redica',
#    'customProject': 'Redica',
#    'customClientLead': 'Arijit Saha',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-10-13',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '397',
#    'fullName2': 'Zuluaga Suarez, Daniel',
#    'customClientStartDate': '2022-06-29',
#    'customClient': 'Redica',
#    'customProject': 'Redica',
#    'customClientLead': 'Arijit Saha',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-08-19',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'},
#   {'id': '397',
#    'fullName2': 'Zuluaga Suarez, Daniel',
#    'customClientStartDate': '2022-06-29',
#    'customClient': 'Redica',
#    'customProject': 'Redica',
#    'customClientLead': 'Arijit Saha',
#    'customDevSavantTeamlead': 'Efraín Galvis Amaya',
#    'customDevSavantTechlead': 'Efraín Galvis Amaya',
#    'customSeniorityfrentealcliente': 'Senior',
#    '4047': '2022-06-29',
#    'location': 'DevSavant Inc',
#    'division': 'Development',
#    'department': 'Operations',
#    'jobTitle': 'Data Engineer',
#    '91': 'Efraín Galvis Amaya'}]}

# %%
# Try with the custom reports out to get the same fieds than the custom reports. 
api_request_reports(fields = ['fullName2', 'payType', 'customCompanyCost1', 'customNetPayments1',
                             'customContractType1','4293',  '4295', '4170'], title = 'test-1', token=TOKEN)
# Out:
# Request ok
# {'title': 'test-1',
#  'fields': [{'id': 'fullName2',
#    'type': 'text',
#    'name': 'Last Name, First Name'},
#   {'id': 'payType', 'type': 'pay_type', 'name': 'Pay type'},
#   {'id': 4293, 'type': 'text', 'name': 'College/Institution'},
#   {'id': 4295, 'type': 'text', 'name': 'Major/Specialization'},
#   {'id': 4170, 'type': 'list', 'name': 'Visa'}],
#  'employees': [{'id': '411',
#    'fullName2': 'Posada, Santiago',
#    'payType': None,
#    '4293': None,
#    '4295': None,
#    '4170': None},
#   {'id': '445',
#    'fullName2': 'Perez, Gonzalo',
#    'payType': None,
#    '4293': None,
#    '4295': None,
#    '4170': None},
#   {'id': '446',
#    'fullName2': 'testeado, Test_1',
#    'payType': None,
#    '4293': None,
#    '4295': None,
#    '4170': None},
#   {'id': '450',
#    'fullName2': 'Rodriguez, Alejandro',
#    'payType': None,
#    '4293': 'Instituto triangulo',
#    '4295': 'Esponjas',
#    '4170': 'B2'}]}

# %%
url = "https://api.bamboohr.com/api/gateway.php/devsavant/v1/reports/364?format=json&fd=no&onlyCurrent=false"
headers = {
    "Accept": "application/json",
    "authorization": authorization
}
response = requests.get(url, headers=headers)
response.json()
# Out:
# {'title': 'Reporte2',
#  'fields': [{'id': 'fullName2',
#    'type': 'text',
#    'name': 'Last Name, First Name'},
#   {'id': 'payRateEffectiveDate', 'type': 'date', 'name': 'Compensation: Date'},
#   {'id': 'paySchedule', 'type': 'pay_schedule', 'name': 'Pay Schedule'},
#   {'id': 'payType', 'type': 'pay_type', 'name': 'Pay type'},
#   {'id': 'payRate', 'type': 'currency', 'name': 'Pay rate'},
#   {'id': 'payRate', 'type': 'text', 'name': 'Pay rate - Currency code'},
#   {'id': 'payPer', 'type': 'paid_per', 'name': 'Paid per'},
#   {'id': 'exempt', 'type': 'exempt', 'name': 'Overtime Status'},
#   {'id': 'overtimeRate', 'type': 'currency', 'name': 'Overtime Rate'},
#   {'id': 'overtimeRate',
#    'type': 'text',
#    'name': 'Overtime Rate - Currency code'},
#   {'id': 'payChangeReason',
#    'type': 'list',
#    'name': 'Compensation Change Reason'},
#   {'id': 4045, 'type': 'text', 'name': 'Compensation comments'},
#   {'id': 'customEffectiveDate', 'type': 'date', 'name': 'Effective Date'},
#   {'id': 'customPaySchedule', 'type': 'list', 'name': 'Pay Schedule'},
#   {'id': 'customPayrollCost', 'type': 'currency', 'name': 'Payroll Cost'},
#   {'id': '4605.1', 'type': 'text', 'name': 'Payroll Cost - Currency code'},
#   {'id': 'customCompanyCost1', 'type': 'currency', 'name': 'Company Cost'},
#   {'id': '4580.1', 'type': 'text', 'name': 'Company Cost - Currency code'},
#   {'id': 'customGrossCompensation',
#    'type': 'currency',
#    'name': 'Gross Compensation'},
#   {'id': '4590.1',
#    'type': 'text',
#    'name': 'Gross Compensation - Currency code'},
#   {'id': 'customNetPayments1', 'type': 'currency', 'name': 'Net Payments'},
#   {'id': '4582.1', 'type': 'text', 'name': 'Net Payments - Currency code'},
#   {'id': 'customSalary', 'type': 'currency', 'name': 'Salary'},
#   {'id': '4583.1', 'type': 'text', 'name': 'Salary - Currency code'},
#   {'id': 'customHousingBonus1', 'type': 'currency', 'name': 'Housing Bonus'},
#   {'id': '4591.1', 'type': 'text', 'name': 'Housing Bonus - Currency code'},
#   {'id': 'customFlexibilityScheme1',
#    'type': 'text',
#    'name': 'Flexibility Scheme'},
#   {'id': 'customContractType1', 'type': 'list', 'name': 'Contract Type'},
#   {'id': 'customSalaryType1', 'type': 'list', 'name': 'Salary Type'},
#   {'id': 'customChangeReason', 'type': 'list', 'name': 'Change Reason'},
#   {'id': 'customComments1', 'type': 'textarea', 'name': 'Comments'},
#   {'id': 'customEffectiveDate2', 'type': 'date', 'name': 'Effective Date'},
#   {'id': 'customSeniority', 'type': 'list', 'name': 'Seniority'},
#   {'id': 'customSublevel', 'type': 'list', 'name': 'Sublevel'},
#   {'id': 'customBankName', 'type': 'text', 'name': 'Bank Name'},
#   {'id': 'customBankAccountType', 'type': 'list', 'name': 'Bank Account Type'},
#   {'id': 'customRoutingNumber', 'type': 'text', 'name': 'Routing Number'},
#   {'id': 'customAccountNumber', 'type': 'text', 'name': 'Account Number'},
#   {'id': 'customSwiftCode', 'type': 'text', 'name': 'Swift Code'},
#   {'id': 'customCountry', 'type': 'list', 'name': 'Country'}],
#  'employees': [{'id': '445',
#    'fullName2': 'Perez, Gonzalo',
#    'payRateEffectiveDate': '2023-02-28',
#    'paySchedule': 'Monthly',
#    'payType': 'Salary',
#    'payRate': '15000000.00 COP',
#    'payPer': 'Month',
#    'exempt': 'Non-exempt',
#    'overtimeRate': '290000.00 COP',
#    'payChangeReason': 'New Hire',
#    '4045': 'Se gana aumento',
#    'customEffectiveDate': '2022-12-16',
#    'customPaySchedule': 'Monthly',
#    'customPayrollCost': '3547896.00 COP',
#    '4605.1': 'COP',
#    'customCompanyCost1': '3547896.00 COP',
#    '4580.1': 'COP',
#    'customGrossCompensation': '4589632.00 COP',
#    '4590.1': 'COP',
#    'customNetPayments1': '3200000.00 COP',
#    '4582.1': 'COP',
#    'customSalary': '1900000.00 COP',
#    '4583.1': 'COP',
#    'customHousingBonus1': '1000000.00 COP',
#    '4591.1': 'COP',
#    'customFlexibilityScheme1': '60/40',
#    'customContractType1': 'Termino Indefinido',
#    'customSalaryType1': 'Ordinario',
#    'customChangeReason': 'New Hire',
#    'customComments1': None,
#    'customEffectiveDate2': '2023-01-31',
#    'customSeniority': None,
#    'customSublevel': None,
#    'customBankName': 'BANCOLOMBIA',
#    'customBankAccountType': 'Ahorros',
#    'customRoutingNumber': '1225',
#    'customAccountNumber': '1321564987882',
#    'customSwiftCode': '545',
#    'customCountry': 'Colombia'},
#   {'id': '411',
#    'fullName2': 'Posada, Santiago',
#    'payRateEffectiveDate': None,
#    'paySchedule': None,
#    'payType': None,
#    'payRate': ' COP',
#    'payPer': None,
#    'exempt': None,
#    'overtimeRate': ' COP',
#    'payChangeReason': None,
#    '4045': None,
#    'customEffectiveDate': '2022-07-31',
#    'customPaySchedule': 'Monthly',
#    'customPayrollCost': '2500000.00 COP',
#    '4605.1': 'COP',
#    'customCompanyCost1': '3845698.00 COP',
#    '4580.1': 'COP',
#    'customGrossCompensation': '4528793.00 COP',
#    '4590.1': 'COP',
#    'customNetPayments1': '3000000.00 COP',
#    '4582.1': 'COP',
#    'customSalary': '1548789.00 COP',
#    '4583.1': 'COP',
#    'customHousingBonus1': '789547.00 COP',
#    '4591.1': 'COP',
#    'customFlexibilityScheme1': '60/40',
#    'customContractType1': 'Termino Indefinido',
#    'customSalaryType1': 'Ordinario',
#    'customChangeReason': 'New Hire',
#    'customComments1': None,
#    'customEffectiveDate2': None,
#    'customSeniority': None,
#    'customSublevel': None,
#    'customBankName': None,
#    'customBankAccountType': None,
#    'customRoutingNumber': None,
#    'customAccountNumber': None,
#    'customSwiftCode': None,
#    'customCountry': None},
#   {'id': '450',
#    'fullName2': 'Rodriguez, Alejandro',
#    'payRateEffectiveDate': None,
#    'paySchedule': None,
#    'payType': None,
#    'payRate': ' COP',
#    'payPer': None,
#    'exempt': None,
#    'overtimeRate': ' COP',
#    'payChangeReason': None,
#    '4045': None,
#    'customEffectiveDate': None,
#    'customPaySchedule': None,
#    'customPayrollCost': ' COP',
#    '4605.1': None,
#    'customCompanyCost1': ' COP',
#    '4580.1': None,
#    'customGrossCompensation': ' COP',
#    '4590.1': None,
#    'customNetPayments1': ' COP',
#    '4582.1': None,
#    'customSalary': ' COP',
#    '4583.1': None,
#    'customHousingBonus1': ' COP',
#    '4591.1': None,
#    'customFlexibilityScheme1': None,
#    'customContractType1': None,
#    'customSalaryType1': None,
#    'customChangeReason': None,
#    'customComments1': None,
#    'customEffectiveDate2': None,
#    'customSeniority': None,
#    'customSublevel': None,
#    'customBankName': None,
#    'customBankAccountType': None,
#    'customRoutingNumber': None,
#    'customAccountNumber': None,
#    'customSwiftCode': None,
#    'customCountry': None},
#   {'id': '446',
#    'fullName2': 'testeado, Test_1',
#    'payRateEffectiveDate': None,
#    'paySchedule': None,
#    'payType': None,
#    'payRate': ' COP',
#    'payPer': None,
#    'exempt': None,
#    'overtimeRate': ' COP',
#    'payChangeReason': None,
#    '4045': None,
#    'customEffectiveDate': None,
#    'customPaySchedule': None,
#    'customPayrollCost': ' COP',
#    '4605.1': None,
#    'customCompanyCost1': ' COP',
#    '4580.1': None,
#    'customGrossCompensation': ' COP',
#    '4590.1': None,
#    'customNetPayments1': ' COP',
#    '4582.1': None,
#    'customSalary': ' COP',
#    '4583.1': None,
#    'customHousingBonus1': ' COP',
#    '4591.1': None,
#    'customFlexibilityScheme1': None,
#    'customContractType1': None,
#    'customSalaryType1': None,
#    'customChangeReason': None,
#    'customComments1': None,
#    'customEffectiveDate2': None,
#    'customSeniority': None,
#    'customSublevel': None,
#    'customBankName': None,
#    'customBankAccountType': None,
#    'customRoutingNumber': None,
#    'customAccountNumber': None,
#    'customSwiftCode': None,
#    'customCountry': None}]}
